# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
amazon= pd.read_csv("C:\\Users\\Yadav\\Downloads\\DS-assignment\\DS-Assignment_Part_2_data_set\\amz_com-ecommerce_sample.csv",encoding="latin")

# %%
amazon.shape
# Out:
# (20000, 15)

# %%
flipkart= pd.read_csv("C:\\Users\\Yadav\\Downloads\\DS-assignment\\DS-Assignment_Part_2_data_set\\flipkart_com-ecommerce_sample.csv",encoding="latin")

# %%
flipkart.shape
# Out:
# (20000, 15)

# %%
flipkart.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
amazon.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
data=flipkart.merge(amazon,on="uniq_id")

# %%
data.head(1)
# Out:
#                             uniq_id          crawl_timestamp_x  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
#
#                                        product_url_x  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
#
#                         product_name_x  \
# 0  Alisha Solid Women's Cycling Shorts
#
#                              product_category_tree_x             pid_x  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
#
#    retail_price_x  discounted_price_x  \
# 0           999.0               379.0
#
#                                              image_x  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...
#
#    is_FK_Advantage_product_x  ...             pid_y retail_price_y  \
# 0                      False  ...  SRTEH2FF9KEDEFGF            982
#
#   discounted_price_y                                            image_y  \
# 0                438  ["http://img5a.flixcart.com/image/short/u/4/a/...
#
# ...

# %%
data=data[["uniq_id","product_name_x","retail_price_x","discounted_price_x","product_name_y","retail_price_y","discounted_price_y"]]

# %%
data.rename(columns={"product_name_x":"Product name in Flipkart","retail_price_x":"Retail Price in Flipkart","discounted_price_x":"Discounted Price in Flipkart"},inplace=True)
data.rename(columns={"product_name_y":"Product name in Amazon","retail_price_y":"Retail Price in Amazon","discounted_price_y":"Discounted Price in Amazon"},inplace=True)

# %%
data.head()
# Out:
#                             uniq_id               Product name in Flipkart  \
# 0  c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# 2  f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 3  0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#    Retail Price in Flipkart  Discounted Price in Flipkart  \
# 0                     999.0                         379.0
# 1                   32157.0                       22646.0
# 2                     999.0                         499.0
# 3                     699.0                         267.0
# 4                     220.0                         210.0
#
#                   Product name in Amazon  Retail Price in Amazon  \
# 0    Alisha Solid Women's Cycling Shorts                     982
# ...

# %%
flipkart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
flipkart.head(1)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
#
#                           product_name  \
# 0  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
#
#         overall_rating   brand  \
# 0  No rating available  Alisha
#
# ...

# %%
df=flipkart[["uniq_id","product_name","product_category_tree","description","product_rating","brand"]]

# %%
df.head(1)
# Out:
#                             uniq_id                         product_name  \
# 0  c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
#
#     brand
# 0  Alisha

# %%
df.isnull().sum()
# Out:
# uniq_id                     0
# product_name                0
# product_category_tree       0
# description                 2
# product_rating              0
# brand                    5864
# dtype: int64

# %%
df.dropna(inplace=True)
df.duplicated().sum()
# Out:
# C:\Users\Yadav\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 0

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns="index",inplace=True)
# Out:
# C:\Users\Yadav\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(2)
# Out:
#                             uniq_id                         product_name  \
# 0  c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor Fabric Double Sofa Bed
#
#                                product_category_tree  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 1  ["Furniture >> Living Room Furniture >> Sofa B...
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
#
#           brand
# 0        Alisha
# 1  FabHomeDecor

# %%
df.iloc[1]["product_category_tree"]
# Out:
# '["Furniture >> Living Room Furniture >> Sofa Beds & Futons >> FabHomeDecor Fabric Double Sofa Bed (Finish Colo..."]'

# %%
import re
import ast
def convert(df):
    l=[]
    for i in df["product_category_tree"]:
        i=str(i)
        i=re.sub(r'\s\>\>\s',",",i)
        l.append([re.sub('\[|\]|\"|\'',"",i)])
    return l
#df["product_category_tree"].iloc[0]

# %%
df["product_category_tree"]=convert(df)
# Out:
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/1813907666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["product_category_tree"]=convert(df)

# %%
df["product_category_tree"][:3]
# Out:
# 0    [Clothing,Womens Clothing,Lingerie, Sleep & Sw...
# 1    [Furniture,Living Room Furniture,Sofa Beds & F...
# 2     [Footwear,Womens Footwear,Ballerinas,AW Bellies]
# Name: product_category_tree, dtype: object

# %%
df.head(1)
# Out:
#                             uniq_id                         product_name  \
# 0  c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree  \
# 0  [Clothing,Womens Clothing,Lingerie, Sleep & Sw...
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
#
#     brand
# 0  Alisha

# %%
df["description"]=df["description"].apply(lambda x:x.split())
df["product_rating"]=df["product_rating"].apply(lambda x : x.split())
df["brand"]=df["brand"].apply(lambda x: x.split())
# Out:
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/3727397691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["description"]=df["description"].apply(lambda x:x.split())
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/3727397691.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["product_rating"]=df["product_rating"].apply(lambda x : x.split())
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/3727397691.py:3: SettingWithCopyWarning:
# ...

# %%
df.head(1)
# Out:
#                             uniq_id                         product_name  \
# 0  c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree  \
# 0  [Clothing,Womens Clothing,Lingerie, Sleep & Sw...
#
#                                          description           product_rating  \
# 0  [Key, Features, of, Alisha, Solid, Women's, Cy...  [No, rating, available]
#
#       brand
# 0  [Alisha]

# %%
df["product_category_tree"]=df["product_category_tree"].apply(lambda x: [i.replace(" ","") for i in x])
df["description"]=df["description"].apply(lambda x: [i.replace(" ","") for i in x])
df["product_rating"]=df["product_rating"].apply(lambda x: [i.replace(" ","") for i in x])
df["brand"]=df["brand"].apply(lambda x: [i.replace(" ","") for i in x])
# Out:
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/440683289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["product_category_tree"]=df["product_category_tree"].apply(lambda x: [i.replace(" ","") for i in x])
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/440683289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["description"]=df["description"].apply(lambda x: [i.replace(" ","") for i in x])
# ...

# %%
df.head(1)
# Out:
#                             uniq_id                         product_name  \
# 0  c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree  \
# 0  [Clothing,WomensClothing,Lingerie,Sleep&Swimwe...
#
#                                          description           product_rating  \
# 0  [Key, Features, of, Alisha, Solid, Women's, Cy...  [No, rating, available]
#
#       brand
# 0  [Alisha]

# %%
df["tags"]=df["product_category_tree"]+df["description"]+df["product_rating"]+df["brand"]
# Out:
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/2818687435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["product_category_tree"]+df["description"]+df["product_rating"]+df["brand"]

# %%
df["tags"]=df["tags"].apply(lambda x : " ".join(x))
df["tags"]=df["tags"].apply(lambda x : x.lower())
df["tags"]=df["tags"].apply(lambda x : x.replace(","," "))
# Out:
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/459680443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["tags"].apply(lambda x : " ".join(x))
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/459680443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["tags"].apply(lambda x : x.lower())
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/459680443.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
df["tags"]=df["tags"].apply(stem)
# Out:
# C:\Users\Yadav\AppData\Local\Temp/ipykernel_1724/959895146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["tags"].apply(stem)

# %%
df["tags"][0]
# Out:
# "cloth womenscloth lingeri sleep&swimwear short alishashort alishasolidwomenscyclingshort key featur of alisha solid women' cycl short cotton lycra navi red navi specif of alisha solid women' cycl short short detail number of content in sale packag pack of 3 fabric cotton lycra type cycl short gener detail pattern solid ideal for women' fabric care gentl machin wash in lukewarm water do not bleach addit detail style code altht_3p_21 in the box 3 short no rate avail alisha"

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=5000,stop_words="english")

# %%
vector=cv.fit_transform(df["tags"]).toarray()

# %%
vector.shape
# Out:
# (14135, 5000)

# %%
cv.get_feature_names()
# Out:
# C:\Users\Yadav\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '001',
#  '01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '050',
#  '06',
#  '07',
#  '08',
#  '09',
#  '099',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '10000mah',
#  '101',
#  '102',
#  '104',
#  '1049',
#  '105',
#  '105cm',
#  '1080p',
#  '1099',
#  '11',
#  '110',
#  '1100',
#  '110db',
#  '115',
#  '1150',
#  '119',
#  '1195',
#  '1199',
#  '12',
#  '120',
#  '1200',
#  '120cm',
#  '120cmx18',
#  '121',
#  '122',
#  '125',
#  '128',
#  '129',
#  '1299',
#  '12cm',
#  '12v',
#  '13',
#  '130',
#  '1300',
#  '1332',
#  '135',
#  '1350',
#  '135cm',
#  '1380',
#  '1399',
#  '14',
#  '140',
#  '145',
#  '147',
#  '149',
#  '1490',
#  '1499',
#  '14k',
#  '15',
#  '150',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim=cosine_similarity(vector,vector)

# %%
sim.shape

# %%
sim[0]

# %%
def recommend(product):
    product_index=df[df["product_name"]==product].index[0]
    distances=sim[product_index]
    product_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[0]
    id_= df.iloc[product_list[0]]["uniq_id"]
    return data[data["uniq_id"]==id_][["Product name in Flipkart","Retail Price in Flipkart","Discounted Price in Flipkart","Product name in Amazon","Retail Price in Amazon","Discounted Price in Amazon"]]

# %%
recommend("Alisha Solid Women's Cycling Shorts")
